# %% [markdown]
# LGMVIP - DataScience Internship Beginner Level Task
#
# Task 1 :- Image to Pencil Sketch with Python
#
# Author: Sanchit Bansal

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('/content/drive/MyDrive/Dog.jpeg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x487 at 0x7FBBDD20C850>

# %%
grey_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=500x487 at 0x7FBBDC8B2DD0>

# %%
inverted_image = 255 - grey_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=500x487 at 0x7FBBDC8BB050>

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=500x487 at 0x7FBBDC8C8350>

# %%
def pencil_sketch(a, b):
  return cv2.divide(a, 255 - b, scale=256)
pencil_sketch=pencil_sketch(grey_image,blurred)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=500x487 at 0x7FBBDD20C0D0>

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=500x487 at 0x7FBBDC8B2DD0>
# <PIL.Image.Image image mode=L size=500x487 at 0x7FBBDC8B21D0>
